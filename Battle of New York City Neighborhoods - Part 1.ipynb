# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Battle of the Neighborhoods - Tompkins County VS Westchester County

# %% [markdown]
# ## Introduction

# %% [markdown]
# New York is the setting for many popular TV shows, and like many people my age who love to watch American Television Programmes, all of us have fantisized about staying there in one way or another.

# %% [markdown]
# Therefore, I've decided to compare 2 of the most highly ranked counties to live in New York, and determine which county I should move to in the future (yes definitely not joking). I've decided on a few metrics to use to compare the 2 counties to determine once and for all which is the best county to live in New York.

# %% [markdown]
# 1. **Crime Rates**. Obviously I want to feel safe in the county of choice to live in, thus I will compare the crime rates of the two counties and then see how they stack up against National Crime statistics in the US.
#
# 2. **Cost of Living, Salary**. This will determine the quality of life you will be able to enjoy in the counties, thus we will compare statistics on cost of basic utilities, transportation. This helps you determine what lifestyle you will be able to enjoy in each county.
#
# 3. **Schools**. Most people aspire to start a family one day, and want to send their kids to the best schools with the best student-teacher ratios as well as test scores.
#
# 4. **Neighborhood Comparision**. We will take a look at fun facts about each neighborhood to determine which one suits your taste more.
#
# 5. **Overall comparison**. These are the basic factors that everyone will consider and applies to all areas, namely population, tax rates, rent, air quality etc.

# %% [markdown]
# ## Our Problem and Purpose

# %% [markdown]
# Our data set containts the coordinates of all cities in the USA, but it does not include venue information. This is our analyses comes in, to use these location coordinates to tag data points in the 2 neighborhoods, Tompkins County and Westchester County. We will mainly be using **k-means-clustering** as our algorithm.
#
# By determining the proximity of venues, facilities to each other, we can use our analysis to detrmine which neighbourhood to choose.

# %% [markdown]
# ## Background of Data

# %% [markdown]
# I have obtained a dataset of information of all US cities from https://simplemaps.com/data/us-cities. The data contains City Name, County Code, County Name, Density, ID, Latitude, Longitude, Source, State ID, State Name, and Timezone. I will read the data into the a pandas dataframe and slice them into the 2 different neighbourhoods to use in our project. We will also make use of the Foursquare API to determine the venues near each neighborhood to perform analysis on the different clusters in our data.
